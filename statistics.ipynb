# %% [markdown]
# Get only electrodes present

# %%
import mne
from mne.preprocessing import ICA  # Import it explicitly to minimize required code and refer to it more easily

plot = False

## Definitions:

# Define eeg channels for when we need to pass them explicitly as arguments
eeg_channels = ['Cz', 'Fz', 'Fp1', 'F7', 'F3', 'FC1', 'C3', 'FC5', 'FT9', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'PO9', 'O1', 'Pz', 'Oz', 'O2', 'PO10', 'P8', 'P4', 'CP2', 'CP6', 'T8', 'FT10', 'FC6', 'C4', 'FC2', 'F4', 'F8', 'Fp2']
eog_channels=['Fp1', 'Fp2']


### Syntax: mne.io.read_raw_edf(r'file', eog=[list of eog channels], preload=True, speed things up, infer_types=True, discover channel types) 
#raw = mne.io.read_raw_edf(r'EDF+\254362\254362.edf', eog=['Fp1', 'Fp2'], preload=True, infer_types=True) ##NOTE: YOU MUST watch the capitalization!

# raw = mne.io.read_raw_edf(
#     r'EDF+\254362\254362.edf',
#     preload=True,
#     infer_types=True,
#     verbose=True
# )
raw = mne.io.read_raw_edf(
    r'EDF+\254362\254362.edf',
    #eog=['Fp1', 'Fp2'], # Define eog channels!  I suggest trying making a copy of these as eog1 and eog2 ##NOTE: YOU MUST watch the capitalization!
    misc=None, # List of channel names to be considered as miscellaneous (MISC) channels.
    stim_channel=None,  # Set to None if you don't have a stim channel
    exclude=['TimestampS', 'TimestampMs', 'OrTimestampS', 'OrTimestampMs', 'Counter', 'Interpolated', 'HighBitFlex', 'SaturationFlag', 'RawCq', 'Battery', 'BatteryPercent', 'MarkerHardware', 'CQ.Cz', 'CQ.Fz', 'CQ.Fp1', 'CQ.F7', 'CQ.F3', 'CQ.FC1', 'CQ.C3', 'CQ.FC5', 'CQ.FT9', 'CQ.T7', 'CQ.CP5', 'CQ.CP1', 'CQ.P3', 'CQ.P7', 'CQ.PO9', 'CQ.O1', 'CQ.Pz', 'CQ.Oz', 'CQ.O2', 'CQ.PO10', 'CQ.P8', 'CQ.P4', 'CQ.CP2', 'CQ.CP6', 'CQ.T8', 'CQ.FT10', 'CQ.FC6', 'CQ.C4', 'CQ.FC2', 'CQ.F4', 'CQ.F8', 'CQ.Fp2', 'CQ.Overall', 'EQ.SampleRateQua', 'EQ.OVERALL', 'EQ.Cz', 'EQ.Fz', 'EQ.Fp1', 'EQ.F7', 'EQ.F3', 'EQ.FC1', 'EQ.C3', 'EQ.FC5', 'EQ.FT9', 'EQ.T7', 'EQ.CP5', 'EQ.CP1', 'EQ.P3', 'EQ.P7', 'EQ.PO9', 'EQ.O1', 'EQ.Pz', 'EQ.Oz', 'EQ.O2', 'EQ.PO10', 'EQ.P8', 'EQ.P4', 'EQ.CP2', 'EQ.CP6', 'EQ.T8', 'EQ.FT10', 'EQ.FC6', 'EQ.C4', 'EQ.FC2', 'EQ.F4', 'EQ.F8', 'EQ.Fp2', 'MOT.TimestampS', 'MOT.TimestampMs', 'MOT.OrTimestampS', 'MOT.OrTimestampM', 'MOT.CounterMems', 'MOT.Interpolated', 'MOT.Q0', 'MOT.Q1', 'MOT.Q2', 'MOT.Q3', 'MOT.AccX', 'MOT.AccY', 'MOT.AccZ', 'MOT.MagX', 'MOT.MagY', 'MOT.MagZ'],  # Exclude channels you don't want
    preload=True,  # Preload data into memory to speed things up
    infer_types=True,  # Infer channel types from names
    verbose=True  # Set verbosity / output messages
    )

# Print all the available channels in the raw data
print(raw.info['ch_names'])
# Out:
# Extracting EDF parameters from r:\FINAL_EDF_REPO\EDF_analysis\python_code\EDF+\254362\254362.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 143999  =      0.000 ...  1124.992 secs...
# ['Cz', 'Fz', 'Fp1', 'F7', 'F3', 'FC1', 'C3', 'FC5', 'FT9', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'PO9', 'O1', 'Pz', 'Oz', 'O2', 'PO10', 'P8', 'P4', 'CP2', 'CP6', 'T8', 'FT10', 'FC6', 'C4', 'FC2', 'F4', 'F8', 'Fp2']

# %% [markdown]
# exclude = ['TimestampS', 'TimestampMs', 'OrTimestampS', 'OrTimestampMs', 'Counter', 'Interpolated', 'HighBitFlex', 'SaturationFlag', 'RawCq', 'Battery', 'BatteryPercent', 'MarkerHardware', 'CQ.Cz', 'CQ.Fz', 'CQ.Fp1', 'CQ.F7', 'CQ.F3', 'CQ.FC1', 'CQ.C3', 'CQ.FC5', 'CQ.FT9', 'CQ.T7', 'CQ.CP5', 'CQ.CP1', 'CQ.P3', 'CQ.P7', 'CQ.PO9', 'CQ.O1', 'CQ.Pz', 'CQ.Oz', 'CQ.O2', 'CQ.PO10', 'CQ.P8', 'CQ.P4', 'CQ.CP2', 'CQ.CP6', 'CQ.T8', 'CQ.FT10', 'CQ.FC6', 'CQ.C4', 'CQ.FC2', 'CQ.F4', 'CQ.F8', 'CQ.Fp2', 'CQ.Overall', 'EQ.SampleRateQua', 'EQ.OVERALL', 'EQ.Cz', 'EQ.Fz', 'EQ.Fp1', 'EQ.F7', 'EQ.F3', 'EQ.FC1', 'EQ.C3', 'EQ.FC5', 'EQ.FT9', 'EQ.T7', 'EQ.CP5', 'EQ.CP1', 'EQ.P3', 'EQ.P7', 'EQ.PO9', 'EQ.O1', 'EQ.Pz', 'EQ.Oz', 'EQ.O2', 'EQ.PO10', 'EQ.P8', 'EQ.P4', 'EQ.CP2', 'EQ.CP6', 'EQ.T8', 'EQ.FT10', 'EQ.FC6', 'EQ.C4', 'EQ.FC2', 'EQ.F4', 'EQ.F8', 'EQ.Fp2', 'MOT.TimestampS', 'MOT.TimestampMs', 'MOT.OrTimestampS', 'MOT.OrTimestampM', 'MOT.CounterMems', 'MOT.Interpolated', 'MOT.Q0', 'MOT.Q1', 'MOT.Q2', 'MOT.Q3', 'MOT.AccX', 'MOT.AccY', 'MOT.AccZ', 'MOT.MagX', 'MOT.MagY', 'MOT.MagZ']

# %%
import mne
from mne.preprocessing import ICA  # Import it explicitly to minimize required code and refer to it more easily

plot = False

## Definitions:

# Define eeg channels for when we need to pass them explicitly as arguments
eeg_channels = ['Cz', 'Fz', 'Fp1', 'F7', 'F3', 'FC1', 'C3', 'FC5', 'FT9', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'PO9', 'O1', 'Pz', 'Oz', 'O2', 'PO10', 'P8', 'P4', 'CP2', 'CP6', 'T8', 'FT10', 'FC6', 'C4', 'FC2', 'F4', 'F8', 'Fp2']
eog_channels=['Fp1', 'Fp2']


### Syntax: mne.io.read_raw_edf(r'file', eog=[list of eog channels], preload=True, speed things up, infer_types=True, discover channel types) 
#raw = mne.io.read_raw_edf(r'EDF+\254362\254362.edf', eog=['Fp1', 'Fp2'], preload=True, infer_types=True) ##NOTE: YOU MUST watch the capitalization!
raw = mne.io.read_raw_edf(
    r'EDF+\254362\254362.edf',
    misc=None, # List of channel names to be considered as miscellaneous (MISC) channels.
    stim_channel=None,  # Set to None if you don't have a stim channel
    exclude=['TimestampS', 'TimestampMs', 'OrTimestampS', 'OrTimestampMs', 'Counter', 'Interpolated', 'HighBitFlex', 
                'SaturationFlag', 'RawCq', 'Battery', 'BatteryPercent', 'MarkerHardware', 'CQ.Cz', 'CQ.Fz', 'CQ.Fp1', 
                'CQ.F7', 'CQ.F3', 'CQ.FC1', 'CQ.C3', 'CQ.FC5', 'CQ.FT9', 'CQ.T7', 'CQ.CP5', 'CQ.CP1', 'CQ.P3', 'CQ.P7', 
                'CQ.PO9', 'CQ.O1', 'CQ.Pz', 'CQ.Oz', 'CQ.O2', 'CQ.PO10', 'CQ.P8', 'CQ.P4', 'CQ.CP2', 'CQ.CP6', 'CQ.T8', 
                'CQ.FT10', 'CQ.FC6', 'CQ.C4', 'CQ.FC2', 'CQ.F4', 'CQ.F8', 'CQ.Fp2', 'CQ.Overall', 'EQ.SampleRateQua', 
                'EQ.OVERALL', 'EQ.Cz', 'EQ.Fz', 'EQ.Fp1', 'EQ.F7', 'EQ.F3', 'EQ.FC1', 'EQ.C3', 'EQ.FC5', 'EQ.FT9', 
                'EQ.T7', 'EQ.CP5', 'EQ.CP1', 'EQ.P3', 'EQ.P7', 'EQ.PO9', 'EQ.O1', 'EQ.Pz', 'EQ.Oz', 'EQ.O2', 'EQ.PO10', 
                'EQ.P8', 'EQ.P4', 'EQ.CP2', 'EQ.CP6', 'EQ.T8', 'EQ.FT10', 'EQ.FC6', 'EQ.C4', 'EQ.FC2', 'EQ.F4', 'EQ.F8', 
                'EQ.Fp2', 'MOT.TimestampS', 'MOT.TimestampMs', 'MOT.OrTimestampS', 'MOT.OrTimestampM', 'MOT.CounterMems', 
                'MOT.Interpolated', 'MOT.Q0', 'MOT.Q1', 'MOT.Q2', 'MOT.Q3', 'MOT.AccX', 'MOT.AccY', 'MOT.AccZ', 
                'MOT.MagX', 'MOT.MagY', 'MOT.MagZ'],  # Exclude channels you don't want
    preload=True,  # Preload data into memory to speed things up
    infer_types=True,  # Infer channel types from names
    verbose=False  # Set verbosity / output messages
    )

montage = mne.channels.make_standard_montage('standard_1020')
raw.set_montage(montage, on_missing='ignore')
raw.pick('eeg') # Pick only eeg related data!  However, we still have more data then we need!  We'll plot only the channels we want
# raw.plot(picks=eeg_channels, block=True) #Block must be True if working interactively with a .py file.  Also, we are picking only eeg channels

print('Lets compare with and without dc removed:')
if plot:
    raw.pick('eeg').plot(picks=eeg_channels, title = 'Raw Data',block=True, remove_dc=False) # Pick only eeg related data!  However, we still have more data then we need!  We'll plot only the channels we want
    print('DC removed:')
    print('Notice that removing the DC drifts\n makes more data fit on the graph!\n\n')
if plot:
    raw.pick('eeg').plot(picks=eeg_channels, title = 'Raw Data',block=True) # Pick only eeg related data!  However, we still have more data then we need!  We'll plot only the channels we want
    print("Let's filter the raw so that we can see how much it improves the signal!")
filtered = raw.copy().filter(l_freq=1, h_freq=40)
# filtered.pick('eeg') # Pick only eeg related data!  However, we still have more data then we need!  We'll plot only the channels we want
if plot:
    filtered.pick('eeg').plot(picks=eeg_channels, title = 'Filtered Data',block=True) # Pick only eeg related data!  However, we still have more data then we need!  We'll plot only the channels we want
ica = ICA(n_components=32, random_state=97, max_iter="auto")
ica.fit(filtered)


# Find EOG and muscle artifacts
eog_indices, eog_scores = ica.find_bads_eog(filtered, ch_name=['Fp1','Fp2'])
muscle_noise_indices, muscle_noise_scores = ica.find_bads_muscle(filtered)

# Exclude the identified artifact components
ica.exclude = list(set(eog_indices + muscle_noise_indices))

# Apply ICA to the raw data
filtered_clean = ica.apply(filtered.copy())
# raw #Block must be True if working interactively with a .py file.  Also, we are picking only eeg channels
if plot:
    filtered_clean.pick('eeg').plot(picks=eeg_channels, title = 'Filtered Data',block=True)

brain_waves = {
    'Delta': (0.1, 4),
    'Theta': (4, 8),
    'Alpha': (8, 13),
    'Beta Low': (13, 20),
    'Beta High': (20, 30),
    'Gamma': (30, 40)
}
# Define the electrode locations by brain lobes
brain_lobes = {
    'Frontal': ['Fz', 'Fp1', 'F7', 'F3', 'FC1', 'Fp2', 'FC2', 'F4', 'F8'],
    'Temporal': ['FT9', 'T7', 'FT10', 'T8'],
    'Parietal': ['Cz', 'C3', 'CP5', 'CP1', 'P3', 'P7', 'Pz', 'P4', 'CP2', 'CP6'],
    'Occipital': ['PO9', 'O1', 'Oz', 'O2', 'PO10']
}

# Initialize brain_wave_rows for brain lobes
brain_wave_lobes = {lobe: {wave: None for wave in brain_waves} for lobe in brain_lobes}

# Initialize a dictionary to hold the average statistics
brain_wave_lobes_avg = {lobe: {wave: None for wave in brain_waves} for lobe in brain_lobes}

# Initialize a dictionary to hold the statistics
brain_wave_statistics = {wave: {} for wave in brain_waves}

# Initialize brain_wave_rows to get them from DF later
brain_wave_rows = {wave: None for wave in brain_waves}

# Initialize a dictionary to hold the statistics
brain_wave_lobes_statistics = {lobe: {wave: {} for wave in brain_waves} for lobe in brain_lobes}
# Out:
# Lets compare with and without dc removed:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Fitting ICA to data using 32 channels (please be patient, this may take a while)
# Selecting by number: 32 components
# Fitting ICA took 10.6s.
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Effective window size : 16.000 (s)
# Applying ICA to Raw instance
#     Transforming to ICA space (32 components)
#     Zeroing out 19 ICA components
#     Projecting back using 32 PCA components

# %%
pdf_value = filtered_clean.compute_psd(
    method = 'multitaper',
    fmin = 1,
    fmax = 40,
    tmin = 0,
    tmax = 60,
    picks = 'eeg',
    proj = False
)
df = pdf_value.to_data_frame(picks = eeg_channels)
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows

# %%
# Populate brain_wave_lobes with filtered DataFrame rows for each lobe and wave
for lobe, electrodes in brain_lobes.items():
    for wave, (min_freq, max_freq) in brain_waves.items():
        filtered_rows = df[(df['freq'] >= min_freq) & (df['freq'] <= max_freq)][electrodes]
        brain_wave_lobes[lobe][wave] = filtered_rows

# Calculate statistics for each brain wave per electrode location within each lobe
for lobe, waves in brain_wave_lobes.items():
    for wave, rows in waves.items():
        for col in rows.columns:
            desc = rows[col].describe(percentiles=[.25, .5, .75])
            median = rows[col].median()
            brain_wave_lobes_statistics[lobe][wave][col] = {
                'count': desc['count'],
                'mean': desc['mean'],
                'std': desc['std'],
                'min': desc['min'],
                '25%': desc['25%'],
                '50%': median,  # Using median for 50%
                '75%': desc['75%'],
                'max': desc['max'],
            }

# Print the statistics for each lobe and wave to verify
for lobe, waves in brain_wave_lobes_statistics.items():
    print(f'{lobe} statistics:')
    for wave, stats in waves.items():
        print(f'  {wave}:')
        for electrode, stat in stats.items():
            print(f'    {electrode}:')
            for key, value in stat.items():
                print(f'      {key}: {value}')
# Out:
# Frontal statistics:
#   Delta:
#     Fz:
#       count: 180.0
#       mean: 2.2597145977398935e-08
#       std: 2.6376882021133033e-08
#       min: 8.282526717652752e-10
#       25%: 7.863279926258707e-09
#       50%: 1.3181829239885197e-08
#       75%: 2.9020026585886806e-08
#       max: 1.82166257489567e-07
#     Fp1:
#       count: 180.0
#       mean: 1.773211101214501e-08
#       std: 1.7245982635161084e-08
#       min: 7.887393234409731e-10
#       25%: 5.403533901995031e-09
#       50%: 1.0092582687592315e-08
#       75%: 2.8473057176263792e-08
#       max: 1.0517269252477174e-07
#     F7:
#       count: 180.0
#       mean: 1.8477123711264008e-08
#       std: 1.8001415442214647e-08
#       min: 8.709519226901789e-10
#       25%: 5.309326067795057e-09
#       50%: 9.769588456622432e-09
#       75%: 3.179794531201402e-08
#       max: 9.830601708301564e-08
#     F3:
#       count: 180.0
#       mean: 2.484825338011648e-08
#       std: 2.985343020326541e-08
#       min: 1.2314581630250434e-09
#       25%: 6.157683670895044e-09
#       50%: 1.0873744284156168e-08
#       75%: 3.2151109329523775e-08
#       max: 1.4847292675739903e-07
#     FC1:
#       count: 180.0
#       mean: 4.876264172769572e-08
#       std: 5.479017688108103e-08
#       min: 2.1511099522386676e-09
#       25%: 8.5242362087517e-09
#       50%: 1.8935614228375714e-08
#       75%: 7.438980471455211e-08
#       max: 2.285646218594138e-07
#     Fp2:
#       count: 180.0
#       mean: 1.603888295918378e-08
#       std: 1.5402606063804943e-08
#       min: 1.0532117356228288e-09
#       25%: 4.6490346024615425e-09
#       50%: 8.811415055168905e-09
#       75%: 2.4439257872082554e-08
#       max: 9.048646328045169e-08
#     FC2:
#       count: 180.0
#       mean: 1.4786377209378433e-08
#       std: 1.3798465341548862e-08
#       min: 9.591340152488831e-10
#       25%: 4.9063088548004875e-09
#       50%: 8.376675494108178e-09
#       75%: 2.3376737929394716e-08
#       max: 8.638789185134967e-08
#     F4:
#       count: 180.0
#       mean: 1.6537464290351625e-08
#       std: 1.5951031082554586e-08
#       min: 1.0478812669429179e-09
#       25%: 5.118283649245373e-09
#       50%: 9.161512561305961e-09
#       75%: 2.5065156820301216e-08
#       max: 1.0233396191366545e-07
#     F8:
#       count: 180.0
#       mean: 1.7881070535066258e-08
#       std: 1.729430374002732e-08
#       min: 1.151513545398078e-09
#       25%: 5.202307130188982e-09
#       50%: 9.709605226892441e-09
#       75%: 2.681709006862167e-08
#       max: 1.0575537166605123e-07
#   Theta:
#     Fz:
#       count: 240.0
#       mean: 1.6596429661030711e-09
#       std: 1.2142671616730604e-09
#       min: 1.8990756357829162e-10
#       25%: 6.907008705703225e-10
#       50%: 1.232151197888567e-09
tered_rows = df[(df['freq'] >= min_freq) & (df['freq'] <= max_freq)]
    brain_wave_rows[wave] = filtered_rows
    # print(filtered_rows)

# Calculate statistics for each brain wave per electrode location
for wave, rows in brain_wave_rows.items():
    for col in rows.columns:
        if col != 'freq':
            desc = rows[col].describe(percentiles=[.25, .5, .75])
            median = rows[col].median()
            mode = rows[col].mode().values
            brain_wave_statistics[wave][col] = {
                'count': desc['count'],
                'mean': desc['mean'],
                'std': desc['std'],
                'min': desc['min'],
                '25%': desc['25%'],
                '50%': median,  # Using median for 50%
                '75%': desc['75%'],
                'max': desc['max'],
            }

# Print the statistics to verify
for wave, stats in brain_wave_statistics.items():
    print(f'{wave} statistics:')
    for electrode, stat in stats.items():
        print(f'  {electrode}:')
        for key, value in stat.items():
            print(f'    {key}: {value}')
# Out:
# Delta statistics:
#   Cz:
#     count: 180.0
#     mean: 1.7095153765585708e-08
#     std: 1.5095102640466384e-08
#     min: 1.1716261967317877e-09
#     25%: 6.3087834210461425e-09
#     50%: 1.1523946167782626e-08
#     75%: 2.681536815169812e-08
#     max: 1.0538647494273522e-07
#   Fz:
#     count: 180.0
#     mean: 2.2597145977398935e-08
#     std: 2.6376882021133033e-08
#     min: 8.282526717652752e-10
#     25%: 7.863279926258707e-09
#     50%: 1.3181829239885197e-08
#     75%: 2.9020026585886806e-08
#     max: 1.82166257489567e-07
#   Fp1:
#     count: 180.0
#     mean: 1.773211101214501e-08
#     std: 1.7245982635161084e-08
#     min: 7.887393234409731e-10
#     25%: 5.403533901995031e-09
#     50%: 1.0092582687592315e-08
#     75%: 2.8473057176263792e-08
#     max: 1.0517269252477174e-07
#   F7:
#     count: 180.0
#     mean: 1.8477123711264008e-08
#     std: 1.8001415442214647e-08
#     min: 8.709519226901789e-10
#     25%: 5.309326067795057e-09
#     50%: 9.769588456622432e-09
#     75%: 3.179794531201402e-08
#     max: 9.830601708301564e-08
#   F3:
#     count: 180.0
#     mean: 2.484825338011648e-08
#     std: 2.985343020326541e-08
#     min: 1.2314581630250434e-09
#     25%: 6.157683670895044e-09
#     50%: 1.0873744284156168e-08
#     75%: 3.2151109329523775e-08
#     max: 1.4847292675739903e-07
#   FC1:
#     count: 180.0
#     mean: 4.876264172769572e-08
#     std: 5.479017688108103e-08
#     min: 2.1511099522386676e-09
#     25%: 8.5242362087517e-09
#     50%: 1.8935614228375714e-08
#     75%: 7.438980471455211e-08
#     max: 2.285646218594138e-07
#   C3:
#     count: 180.0
#     mean: 1.763953536486107e-08
#     std: 1.536674566249253e-08
#     min: 7.21170388576427e-10
#     25%: 6.761846692392198e-09
#     50%: 1.0907442234026147e-08
#     75%: 2.7626429921873112e-08
#     max: 9.845414728283369e-08
#   FC5:
#     count: 180.0
#     mean: 2.0979130224136734e-08
#     std: 2.0615228286409507e-08
#     min: 1.0142615637036122e-09
#     25%: 5.97727795596932e-09
#     min: 8.69315945423087e-12
#     25%: 3.6537294901361575e-11
#     50%: 5.124270665340481e-11
#     75%: 6.882784762250251e-11
#     max: 1.5659773404663079e-10
#   F8:
#     count: 600.0
#     mean: 6.298653373352578e-11
#     std: 2.724355596204968e-11
#     min: 1.13434032886083e-11
#     25%: 4.258832822014174e-11
#     50%: 5.868047983368227e-11
#     75%: 7.97440113645188e-11
#     max: 1.6308299450537223e-10
#   Fp2:
#     count: 600.0
#     mean: 5.347004499172953e-11
#     std: 2.3575618622053855e-11
#     min: 8.594349666227716e-12
#     25%: 3.57450665587668e-11
#     50%: 4.945681606323964e-11
#     75%: 6.763993987357624e-11
#     max: 1.446962374770984e-10

# %%
# Calculate average across all electrodes within each brain lobe for each brain wave
for lobe, electrodes in brain_lobes.items():
    for wave, (min_freq, max_freq) in brain_waves.items():
        filtered_rows = df[(df['freq'] >= min_freq) & (df['freq'] <= max_freq)][electrodes]
        avg_across_electrodes = filtered_rows.mean(axis=1)  # Calculate mean across electrodes
        brain_wave_lobes_avg[lobe][wave] = avg_across_electrodes.mean()  # Mean of means across frequencies

# Print the averages for each lobe and wave to verify
for lobe, waves in brain_wave_lobes_avg.items():
    print(f'{lobe} average statistics:')
    for wave, value in waves.items():
        print(f'  {wave}: {value}')
# Out:
# Frontal average statistics:
#   Delta: 2.1962341200288916e-08
#   Theta: 1.5894952118626748e-09
#   Alpha: 4.653349794513635e-10
#   Beta Low: 1.4584315087512318e-10
#   Beta High: 6.259405810428495e-11
#   Gamma: 6.055084913879627e-11
# Temporal average statistics:
#   Delta: 1.9029416384029298e-08
#   Theta: 1.2387080638866227e-09
#   Alpha: 4.5556998360567525e-10
#   Beta Low: 1.526325684279623e-10
#   Beta High: 7.81939561933753e-11
#   Gamma: 8.232480756437594e-11
# Parietal average statistics:
#   Delta: 1.6535011470313806e-08
#   Theta: 1.389656272044388e-09
#   Alpha: 6.212755807863648e-10
#   Beta Low: 1.3584989493586538e-10
#   Beta High: 6.504597028870967e-11
#   Gamma: 6.31488328912002e-11
# Occipital average statistics:
#   Delta: 2.1532100676100818e-08
#   Theta: 1.6638945321426884e-09
#   Alpha: 7.018129622105047e-10
#   Beta Low: 2.2516013596702207e-10
#   Beta High: 1.0525313476193045e-10
#   Gamma: 9.794287858251884e-11

# %%
import mne
from mne.preprocessing import ICA  # Import it explicitly to minimize required code and refer to it more easily

plot = False

## Definitions:

# Define eeg channels for when we need to pass them explicitly as arguments
eeg_channels = ['Cz', 'Fz', 'Fp1', 'F7', 'F3', 'FC1', 'C3', 'FC5', 'FT9', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'PO9', 'O1', 'Pz', 'Oz', 'O2', 'PO10', 'P8', 'P4', 'CP2', 'CP6', 'T8', 'FT10', 'FC6', 'C4', 'FC2', 'F4', 'F8', 'Fp2']
eog_channels=['Fp1', 'Fp2']


### Syntax: mne.io.read_raw_edf(r'file', eog=[list of eog channels], preload=True, speed things up, infer_types=True, discover channel types) 
#raw = mne.io.read_raw_edf(r'EDF+\254362\254362.edf', eog=['Fp1', 'Fp2'], preload=True, infer_types=True) ##NOTE: YOU MUST watch the capitalization!
raw = mne.io.read_raw_edf(
    r'EDF+\254362\254362.edf',
    #eog=['Fp1', 'Fp2'], # Define eog channels!  I suggest trying making a copy of these as eog1 and eog2 ##NOTE: YOU MUST watch the capitalization!
    misc=None, # List of channel names to be considered as miscellaneous (MISC) channels.
    stim_channel=None,  # Set to None if you don't have a stim channel
    exclude=[],  # Exclude channels you don't want
    preload=True,  # Preload data into memory to speed things up
    infer_types=True,  # Infer channel types from names
    verbose=True  # Set verbosity / output messages
    )

montage = mne.channels.make_standard_montage('standard_1020')
raw.set_montage(montage, on_missing='ignore')
raw.pick('eeg') # Pick only eeg related data!  However, we still have more data then we need!  We'll plot only the channels we want
# raw.plot(picks=eeg_channels, block=True) #Block must be True if working interactively with a .py file.  Also, we are picking only eeg channels

print('Lets compare with and without dc removed:')
if plot:
    raw.pick('eeg').plot(picks=eeg_channels, title = 'Raw Data',block=True, remove_dc=False) # Pick only eeg related data!  However, we still have more data then we need!  We'll plot only the channels we want
    print('DC removed:')
    print('Notice that removing the DC drifts\n makes more data fit on the graph!\n\n')
if plot:
    raw.pick('eeg').plot(picks=eeg_channels, title = 'Raw Data',block=True) # Pick only eeg related data!  However, we still have more data then we need!  We'll plot only the channels we want
    print("Let's filter the raw so that we can see how much it improves the signal!")
filtered = raw.copy().filter(l_freq=1, h_freq=40)
# filtered.pick('eeg') # Pick only eeg related data!  However, we still have more data then we need!  We'll plot only the channels we want
if plot:
    filtered.pick('eeg').plot(picks=eeg_channels, title = 'Filtered Data',block=True) # Pick only eeg related data!  However, we still have more data then we need!  We'll plot only the channels we want
ica = ICA(n_components=32, random_state=97, max_iter="auto")
ica.fit(filtered)


# Find EOG and muscle artifacts
eog_indices, eog_scores = ica.find_bads_eog(filtered, ch_name=['Fp1','Fp2'])
muscle_noise_indices, muscle_noise_scores = ica.find_bads_muscle(filtered)

# Exclude the identified artifact components
ica.exclude = list(set(eog_indices + muscle_noise_indices))

# Apply ICA to the raw data
filtered_clean = ica.apply(filtered.copy())
# raw #Block must be True if working interactively with a .py file.  Also, we are picking only eeg channels
if plot:
    filtered_clean.pick('eeg').plot(picks=eeg_channels, title = 'Filtered Data',block=True)

brain_waves = {
    'Delta': (0.1, 4),
    'Theta': (4, 8),
    'Alpha': (8, 13),
    'Beta Low': (13, 20),
    'Beta High': (20, 30),
    'Gamma': (30, 40)
}
# Define the electrode locations by brain lobes
brain_lobes = {
    'Frontal': ['Fz', 'Fp1', 'F7', 'F3', 'FC1', 'Fp2', 'FC2', 'F4', 'F8'],
    'Temporal': ['FT9', 'T7', 'FT10', 'T8'],
    'Parietal': ['Cz', 'C3', 'CP5', 'CP1', 'P3', 'P7', 'Pz', 'P4', 'CP2', 'CP6'],
    'Occipital': ['PO9', 'O1', 'Oz', 'O2', 'PO10']
}

# Initialize brain_wave_rows for brain lobes
brain_wave_lobes = {lobe: {wave: None for wave in brain_waves} for lobe in brain_lobes}

# Initialize a dictionary to hold the average statistics
brain_wave_lobes_avg = {lobe: {wave: None for wave in brain_waves} for lobe in brain_lobes}

# Initialize a dictionary to hold the statistics
brain_wave_statistics = {wave: {} for wave in brain_waves}

# Initialize brain_wave_rows to get them from DF later
brain_wave_rows = {wave: None for wave in brain_waves}

# Initialize a dictionary to hold the statistics
brain_wave_lobes_statistics = {lobe: {wave: {} for wave in brain_waves} for lobe in brain_lobes}

pdf_value = filtered_clean.compute_psd(
    method = 'multitaper',
    fmin = 1,
    fmax = 40,
    tmin = 0,
    tmax = 60,
    picks = 'eeg',
    proj = False
)

df = pdf_value.to_data_frame(picks = eeg_channels)

# Populate brain_wave_lobes with filtered DataFrame rows for each lobe and wave
for lobe, electrodes in brain_lobes.items():
    for wave, (min_freq, max_freq) in brain_waves.items():
        filtered_rows = df[(df['freq'] >= min_freq) & (df['freq'] <= max_freq)][electrodes]
        brain_wave_lobes[lobe][wave] = filtered_rows

# Calculate statistics for each brain wave per electrode location within each lobe
for lobe, waves in brain_wave_lobes.items():
    for wave, rows in waves.items():
        for col in rows.columns:
            desc = rows[col].describe(percentiles=[.25, .5, .75])
            median = rows[col].median()
            brain_wave_lobes_statistics[lobe][wave][col] = {
                'count': desc['count'],
                'mean': desc['mean'],
                'std': desc['std'],
                'min': desc['min'],
                '25%': desc['25%'],
                '50%': median,  # Using median for 50%
                '75%': desc['75%'],
                'max': desc['max'],
            }

# Print the statistics for each lobe and wave to verify
for lobe, waves in brain_wave_lobes_statistics.items():
    print(f'{lobe} statistics:')
    for wave, stats in waves.items():
        print(f'  {wave}:')
        for electrode, stat in stats.items():
            print(f'    {electrode}:')
            for key, value in stat.items():
                print(f'      {key}: {value}')
                
pdf_value = filtered_clean.compute_psd(
    method = 'multitaper',
    fmin = 1,
    fmax = 40,
    tmin = 0,
    tmax = 60,
    picks = 'eeg',
    proj = False
)


# Calculate average across all electrodes within each brain lobe for each brain wave
for lobe, electrodes in brain_lobes.items():
    for wave, (min_freq, max_freq) in brain_waves.items():
        filtered_rows = df[(df['freq'] >= min_freq) & (df['freq'] <= max_freq)][electrodes]
        avg_across_electrodes = filtered_rows.mean(axis=1)  # Calculate mean across electrodes
        brain_wave_lobes_avg[lobe][wave] = avg_across_electrodes.mean()  # Mean of means across frequencies

# Print the averages for each lobe and wave to verify
for lobe, waves in brain_wave_lobes_avg.items():
    print(f'{lobe} average statistics:')
    for wave, value in waves.items():
        print(f'  {wave}: {value}')
# Out:
# Extracting EDF parameters from r:\FINAL_EDF_REPO\EDF_analysis\python_code\EDF+\254362\254362.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 143999  =      0.000 ...  1124.992 secs...
# Lets compare with and without dc removed:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.4s
# Fitting ICA to data using 127 channels (please be patient, this may take a while)
# Selecting by number: 32 components
# Fitting ICA took 10.0s.
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4020\1674393006.py:44: RuntimeWarning: Using n_components=32 (resulting in n_components_=32) may lead to an unstable mixing matrix estimation because the ratio between the largest (1.2e+02) and smallest (3.6e-07) variances is too large (> 1e6); consider setting n_components=0.999999 or an integer <= 10
#   ica.fit(filtered)
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Effective window size : 16.000 (s)
# Applying ICA to Raw instance
#     Transforming to ICA space (32 components)
#     Zeroing out 0 ICA components
#     Projecting back using 127 PCA components
#     Using multitaper spectrum estimation with 7 DPSS windows
# Frontal statistics:
#   Delta:
#     Fz:
#       count: 180.0
#       mean: 2.5003397848266703e-08
#       std: 2.8685685571533865e-08
#       min: 1.2112416743719254e-09
#       25%: 8.918441000262351e-09
#       50%: 1.451444119460998e-08
#       min: 2.072265652903685e-11
#       25%: 7.731990403911499e-11
#       50%: 1.0258403016029192e-10
#       75%: 1.3327671986265056e-10
#       max: 2.560609346728973e-10
#     O1:
#       count: 600.0
#       mean: 1.2580034107631975e-10
#       std: 5.04813356123246e-11
#       min: 2.6499696481559525e-11
#       25%: 8.876818120686196e-11
#       50%: 1.190280994190941e-10
#       75%: 1.5472541786879649e-10
#       max: 3.070336317365725e-10
#     Oz:
#       count: 600.0
#       mean: 1.2190175379960645e-10
#       std: 4.998022472050252e-11
#       min: 3.1598248306293397e-11
#       25%: 8.420063195721726e-11
#       50%: 1.1432704659494805e-10
#       75%: 1.527346546453487e-10
#       max: 3.207204572381662e-10
#     O2:
#       count: 600.0
#       mean: 1.367031248151255e-10
#       std: 5.2584114156380354e-11
#       min: 4.7280856337191e-11
#       25%: 9.935139308638598e-11
#       50%: 1.2810496245931663e-10
#       75%: 1.6335927332836445e-10
#       max: 3.785868164633586e-10
#     PO10:
#       count: 600.0
#       mean: 2.7008986191132732e-11
#       std: 1.792157230718442e-11
#       min: 2.1986704867440145e-12
#       25%: 1.4722836533707598e-11
#       50%: 2.214651566032319e-11
#       75%: 3.392882551285359e-11
#       max: 1.0668027141019568e-10
#   Gamma:
#     PO9:
#       count: 600.0
#       mean: 8.35783565368978e-11
#       std: 3.4755242638426616e-11
#       min: 1.5701690549041288e-11
#       25%: 6.005808465622774e-11
#       50%: 7.820865134000947e-11
#       75%: 1.027477685738754e-10
#       max: 2.09149344949041e-10
#     O1:
#       count: 600.0
#       mean: 1.0890289700461759e-10
#       std: 4.6015362211800104e-11
#       min: 2.4734027061738676e-11
#       25%: 7.420065681055166e-11
#       50%: 1.0127660383501339e-10
#       75%: 1.3776477011150012e-10
#       max: 3.018575325822957e-10
#     Oz:
#       count: 600.0
#       mean: 1.109871761224182e-10
#       std: 4.7376735420712924e-11
#       min: 2.2047921299675454e-11
#       25%: 7.368071940363199e-11
#       50%: 1.0277732310853737e-10
#       75%: 1.4074337762205169e-10
#       max: 2.8533453078986857e-10
#     O2:
#       count: 600.0
#       mean: 1.3229772838162314e-10
#       std: 5.3195768240227125e-11
#       min: 3.634799940783641e-11
#       25%: 8.892576142518194e-11
#       50%: 1.275802989226407e-10
#       75%: 1.69933457925274e-10
#       max: 3.0955353648991437e-10
#     PO10:
#       count: 600.0
#       mean: 2.5082163262541033e-11
#       std: 1.2067834062475147e-11
#       min: 6.512876418926378e-12
#       25%: 1.6163997752217605e-11
#       50%: 2.3002226186029918e-11
#       75%: 3.088960848390607e-11
#       max: 7.489621235228682e-11
#     Using multitaper spectrum estimation with 7 DPSS windows
# Frontal average statistics:
#   Delta: 2.822067549083647e-08
#   Theta: 2.3365035705818574e-09
#   Alpha: 6.815960554600237e-10
#   Beta Low: 2.2369925427437096e-10
#   Beta High: 1.0628204451001179e-10
#   Gamma: 8.895720030074982e-11
# Temporal average statistics:
#   Delta: 2.635724234525182e-08
#   Theta: 2.0812108356395783e-09
#   Alpha: 6.633721550392504e-10
#   Beta Low: 2.358281943051122e-10
#   Beta High: 1.1679113084434607e-10
#   Gamma: 1.1407671481830907e-10
# Parietal average statistics:
#   Delta: 2.1783710808149773e-08
#   Theta: 1.6773290466304047e-09
#   Alpha: 7.697450456323508e-10
#   Beta Low: 1.5491577827669372e-10
#   Beta High: 6.903970351840724e-11
#   Gamma: 6.184544585919883e-11
# Occipital average statistics:
#   Delta: 2.7676382983482502e-08
#   Theta: 1.9536538558102185e-09
#   Alpha: 8.877077140785935e-10
#   Beta Low: 2.370907066035776e-10
#   Beta High: 1.0400686746746598e-10
#   Gamma: 9.216966426161955e-11

# %%
import mne
from mne.preprocessing import ICA  # Import it explicitly to minimize required code and refer to it more easily

plot = False

## Definitions:

# Define eeg channels for when we need to pass them explicitly as arguments
eeg_channels = ['Cz', 'Fz', 'Fp1', 'F7', 'F3', 'FC1', 'C3', 'CP5', 'CP1', 'P3', 'P7', 'PO9', 'O1', 'Pz', 'Oz', 'O2', 'PO10', 'P8', 'P4', 'CP2', 'CP6', 'T8', 'FT10', 'FC6', 'C4', 'FC2', 'F4', 'F8', 'Fp2']
eog_channels=['Fp1', 'Fp2']

### Syntax: mne.io.read_raw_edf(r'file', preload=True, infer_types=True)
raw = mne.io.read_raw_edf(
    r'EDF+\254362\254362.edf',
    preload=True,
    infer_types=True,
    verbose=True
)

montage = mne.channels.make_standard_montage('standard_1020')
raw.set_montage(montage, on_missing='ignore')
raw.pick('eeg')

filtered = raw.copy().filter(l_freq=1, h_freq=40)

ica = ICA(n_components=32, random_state=97, max_iter="auto")
ica.fit(filtered)

# Find EOG and muscle artifacts
eog_indices, eog_scores = ica.find_bads_eog(filtered, ch_name=['Fp1','Fp2'])
muscle_noise_indices, muscle_noise_scores = ica.find_bads_muscle(filtered)

# Exclude the identified artifact components
ica.exclude = list(set(eog_indices + muscle_noise_indices))

# Apply ICA to the raw data
filtered_clean = ica.apply(filtered.copy())

# Define brain waves frequency bands
brain_waves = {
    'Delta': (0.1, 4),
    'Theta': (4, 8),
    'Alpha': (8, 13),
    'Beta Low': (13, 20),
    'Beta High': (20, 30),
    'Gamma': (30, 40)
}

# Left, Right, and Midline Hemisphere Electrode Mapping
left_lobes = {
    'Frontal': ['Fp1', 'F7', 'F3', 'FC1'],
    'Temporal': ['FT9', 'T7'],
    'Parietal': ['C3', 'CP5', 'CP1', 'P3', 'P7'],
    'Occipital': ['PO9', 'O1']
}

right_lobes = {
    'Frontal': ['Fp2', 'F8', 'F4', 'FC2'],
    'Temporal': ['FT10', 'T8'],
    'Parietal': ['C4', 'CP6', 'CP2', 'P4', 'P8'],
    'Occipital': ['PO10', 'O2']
}

midline_lobes = {
    'Frontal': ['Fz'],
    'Parietal': ['Cz', 'Pz'],
    'Occipital': ['Oz']
}

# Compute Power Spectral Density (PSD) for filtered data
psd_value = filtered_clean.compute_psd(
    method='multitaper',
    fmin=1,
    fmax=40,
    tmin=0,
    tmax=60,
    picks='eeg',
    proj=False
)

df = psd_value.to_data_frame(picks=eeg_channels)

# Function to compute statistics for a set of electrodes
def compute_stats_for_lobes(lobe_electrodes, df, brain_waves):
    lobe_statistics = {}
    for lobe, electrodes in lobe_electrodes.items():
        lobe_statistics[lobe] = {}
        for wave, (min_freq, max_freq) in brain_waves.items():
            filtered_rows = df[(df['freq'] >= min_freq) & (df['freq'] <= max_freq)][electrodes]
            if not filtered_rows.empty:
                avg_across_electrodes = filtered_rows.mean(axis=1)  # Mean across electrodes
                lobe_statistics[lobe][wave] = avg_across_electrodes.mean()  # Mean of means across frequencies
            else:
                lobe_statistics[lobe][wave] = None
    return lobe_statistics

# Compute statistics for left, right, and midline lobes
left_stats = compute_stats_for_lobes(left_lobes, df, brain_waves)
right_stats = compute_stats_for_lobes(right_lobes, df, brain_waves)
midline_stats = compute_stats_for_lobes(midline_lobes, df, brain_waves)

# Compute total average (including both left, right, and midline)
def compute_total_average(left_stats, right_stats, midline_stats):
    total_stats = {}
    for wave in brain_waves:
        wave_values = []
        for lobe in left_stats:
            if left_stats[lobe][wave] is not None:
                wave_values.append(left_stats[lobe][wave])
        for lobe in right_stats:
            if right_stats[lobe][wave] is not None:
                wave_values.append(right_stats[lobe][wave])
        for lobe in midline_stats:
            if midline_stats[lobe][wave] is not None:
                wave_values.append(midline_stats[lobe][wave])
        total_stats[wave] = sum(wave_values) / len(wave_values) if wave_values else None
    return total_stats

total_stats = compute_total_average(left_stats, right_stats, midline_stats)

# Print the statistics in a tabular format (Left, Total, Right)
def print_table(left_stats, total_stats, right_stats):
    header = f"{'Wave':<15} {'Left':<15} {'Total':<15} {'Right':<15}"
    print(header)
    print("=" * len(header))
    for wave in brain_waves:
        left_value = f"{left_stats.get('Frontal', {}).get(wave, 'N/A'):.2f}" if left_stats.get('Frontal', {}).get(wave) else "N/A"
        right_value = f"{right_stats.get('Frontal', {}).get(wave, 'N/A'):.2f}" if right_stats.get('Frontal', {}).get(wave) else "N/A"
        total_value = f"{total_stats.get(wave, 'N/A'):.2f}" if total_stats.get(wave) else "N/A"
        row = f"{wave:<15} {left_value:<15} {total_value:<15} {right_value:<15}"
        print(row)

# Print the final table
print_table(left_stats, total_stats, right_stats)
# Out:
# Extracting EDF parameters from r:\FINAL_EDF_REPO\EDF_analysis\python_code\EDF+\254362\254362.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 143999  =      0.000 ...  1124.992 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.4s
# Fitting ICA to data using 127 channels (please be patient, this may take a while)
# Selecting by number: 32 components
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4020\2213955289.py:27: RuntimeWarning: Using n_components=32 (resulting in n_components_=32) may lead to an unstable mixing matrix estimation because the ratio between the largest (1.2e+02) and smallest (3.6e-07) variances is too large (> 1e6); consider setting n_components=0.999999 or an integer <= 10
#   ica.fit(filtered)
# Fitting ICA took 9.6s.
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Effective window size : 16.000 (s)
# Applying ICA to Raw instance
#     Transforming to ICA space (32 components)
#     Zeroing out 0 ICA components
#     Projecting back using 127 PCA components
#     Using multitaper spectrum estimation with 7 DPSS windows
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 98
#      95     return lobe_statistics
#      97 # Compute statistics for left, right, and midline lobes
# ---> 98 left_stats = compute_stats_for_lobes(left_lobes, df, brain_waves)
#      99 right_stats = compute_stats_for_lobes(right_lobes, df, brain_waves)
#     100 midline_stats = compute_stats_for_lobes(midline_lobes, df, brain_waves)
#
# Cell In[8], line 89, in compute_stats_for_lobes(lobe_electrodes, df, brain_waves)
#      87 lobe_statistics[lobe] = {}
#      88 for wave, (min_freq, max_freq) in brain_waves.items():
# ---> 89     filtered_rows = df[(df['freq'] >= min_freq) & (df['freq'] <= max_freq)][electrodes]
#      90     if not filtered_rows.empty:
#      91         avg_across_electrodes = filtered_rows.mean(axis=1)  # Mean across electrodes
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['FT9', 'T7'], dtype='object')] are in the [columns]"

# %%
print(df.columns)
# Out:
# Index(['freq', 'Cz', 'Fz', 'Fp1', 'F7', 'F3', 'FC1', 'C3', 'CP5', 'CP1', 'P3',
#        'P7', 'PO9', 'O1', 'Pz', 'Oz', 'O2', 'PO10', 'P8', 'P4', 'CP2', 'CP6',
#        'T8', 'FT10', 'FC6', 'C4', 'FC2', 'F4', 'F8', 'Fp2'],
#       dtype='object')

# %%
# Print all the available channels in the raw data
print(raw.info['ch_names'])
# Out:
# ['TimestampS', 'TimestampMs', 'OrTimestampS', 'OrTimestampMs', 'Counter', 'Interpolated', 'Cz', 'Fz', 'Fp1', 'F7', 'F3', 'FC1', 'C3', 'FC5', 'FT9', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'PO9', 'O1', 'Pz', 'Oz', 'O2', 'PO10', 'P8', 'P4', 'CP2', 'CP6', 'T8', 'FT10', 'FC6', 'C4', 'FC2', 'F4', 'F8', 'Fp2', 'HighBitFlex', 'SaturationFlag', 'RawCq', 'Battery', 'BatteryPercent', 'MarkerHardware', 'CQ.Cz', 'CQ.Fz', 'CQ.Fp1', 'CQ.F7', 'CQ.F3', 'CQ.FC1', 'CQ.C3', 'CQ.FC5', 'CQ.FT9', 'CQ.T7', 'CQ.CP5', 'CQ.CP1', 'CQ.P3', 'CQ.P7', 'CQ.PO9', 'CQ.O1', 'CQ.Pz', 'CQ.Oz', 'CQ.O2', 'CQ.PO10', 'CQ.P8', 'CQ.P4', 'CQ.CP2', 'CQ.CP6', 'CQ.T8', 'CQ.FT10', 'CQ.FC6', 'CQ.C4', 'CQ.FC2', 'CQ.F4', 'CQ.F8', 'CQ.Fp2', 'CQ.Overall', 'EQ.SampleRateQua', 'EQ.OVERALL', 'EQ.Cz', 'EQ.Fz', 'EQ.Fp1', 'EQ.F7', 'EQ.F3', 'EQ.FC1', 'EQ.C3', 'EQ.FC5', 'EQ.FT9', 'EQ.T7', 'EQ.CP5', 'EQ.CP1', 'EQ.P3', 'EQ.P7', 'EQ.PO9', 'EQ.O1', 'EQ.Pz', 'EQ.Oz', 'EQ.O2', 'EQ.PO10', 'EQ.P8', 'EQ.P4', 'EQ.CP2', 'EQ.CP6', 'EQ.T8', 'EQ.FT10', 'EQ.FC6', 'EQ.C4', 'EQ.FC2', 'EQ.F4', 'EQ.F8', 'EQ.Fp2', 'MOT.TimestampS', 'MOT.TimestampMs', 'MOT.OrTimestampS', 'MOT.OrTimestampM', 'MOT.CounterMems', 'MOT.Interpolated', 'MOT.Q0', 'MOT.Q1', 'MOT.Q2', 'MOT.Q3', 'MOT.AccX', 'MOT.AccY', 'MOT.AccZ', 'MOT.MagX', 'MOT.MagY', 'MOT.MagZ']

# %%
import mne
from mne.preprocessing import ICA

# Define EEG channels
eeg_channels = [
    'Cz', 'Fz', 'Fp1', 'F7', 'F3', 'FC1', 'C3', 'FC5', 'FT9', 'T7', 
    'CP5', 'CP1', 'P3', 'P7', 'PO9', 'O1', 'Pz', 'Oz', 'O2', 'PO10', 
    'P8', 'P4', 'CP2', 'CP6', 'T8', 'FT10', 'FC6', 'C4', 'FC2', 'F4', 'F8', 'Fp2'
]

# Load the raw data
raw = mne.io.read_raw_edf(
    r'EDF+\254362\254362.edf',
    preload=True,
    infer_types=True
)

# Set montage and pick only the specified EEG channels
montage = mne.channels.make_standard_montage('standard_1020')
raw.set_montage(montage, on_missing='ignore')
raw.pick_channels(eeg_channels)

# Filter the data
filtered = raw.copy().filter(l_freq=1, h_freq=40)

# Apply ICA for artifact removal
ica = ICA(n_components=32, random_state=97, max_iter="auto")
ica.fit(filtered)

# Find and exclude EOG and muscle artifacts
eog_indices, eog_scores = ica.find_bads_eog(filtered, ch_name=['Fp1', 'Fp2'])
muscle_noise_indices, muscle_noise_scores = ica.find_bads_muscle(filtered)
ica.exclude = list(set(eog_indices + muscle_noise_indices))
filtered_clean = ica.apply(filtered.copy())

# Define brain waves and their frequency ranges
brain_waves = {
    'Delta': (0.1, 4),
    'Theta': (4, 8),
    'Alpha': (8, 13),
    'Beta Low': (13, 20),
    'Beta High': (20, 30),
    'Gamma': (30, 40)
}

# Compute power spectral density (PSD)
psd = filtered_clean.compute_psd(
    method='multitaper',
    fmin=1, fmax=40,
    tmin=0, tmax=60,
    picks='eeg',
    proj=False
)

df = psd.to_data_frame(picks=eeg_channels)

# Define lobes and their corresponding channels
lobes = {
    'Left': ['Fp1', 'F7', 'F3', 'FC1', 'C3', 'CP1', 'P3', 'P7', 'O1', 'PO9'],
    'Right': ['Fp2', 'F8', 'F4', 'FC2', 'C4', 'CP2', 'P4', 'P8', 'O2', 'PO10'],
    'Midline': ['Cz', 'Fz', 'Pz', 'Oz']
}

# Compute statistics for lobes and brain waves
def compute_stats_for_lobes(lobe_electrodes, df, brain_waves):
    lobe_statistics = {}
    for lobe, electrodes in lobe_electrodes.items():
        lobe_statistics[lobe] = {}
        for wave, (min_freq, max_freq) in brain_waves.items():
            filtered_rows = df[(df['freq'] >= min_freq) & (df['freq'] <= max_freq)][electrodes]
            if not filtered_rows.empty:
                avg_across_electrodes = filtered_rows.mean(axis=1)
                lobe_statistics[lobe][wave] = avg_across_electrodes.mean()
    return lobe_statistics

# Compute left, right, and midline lobe statistics
left_stats = compute_stats_for_lobes({'Left': lobes['Left']}, df, brain_waves)
right_stats = compute_stats_for_lobes({'Right': lobes['Right']}, df, brain_waves)
midline_stats = compute_stats_for_lobes({'Midline': lobes['Midline']}, df, brain_waves)

# Print the statistics in tabular format
print(f"{'Brain Wave':<12}{'Left':<10}{'Total':<10}{'Right':<10}")
for wave in brain_waves.keys():
    left_value = left_stats['Left'].get(wave, 'N/A')
    right_value = right_stats['Right'].get(wave, 'N/A')
    mid_value = midline_stats['Midline'].get(wave, 'N/A')
    total_value = (left_value + right_value + mid_value) / 3 if isinstance(left_value, float) else 'N/A'
    print(f"{wave:<12}{left_value:<10}{total_value:<10}{right_value:<10}")
# Out:
# Extracting EDF parameters from r:\FINAL_EDF_REPO\EDF_analysis\EDF+\254362\254362.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 143999  =      0.000 ...  1124.992 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Fitting ICA to data using 32 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Selecting by number: 32 components
# Fitting ICA took 8.7s.
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Effective window size : 16.000 (s)
# Applying ICA to Raw instance
#     Transforming to ICA space (32 components)
#     Zeroing out 19 ICA components
#     Projecting back using 32 PCA components
#     Using multitaper spectrum estimation with 7 DPSS windows
# Brain Wave  Left      Total     Right
# Delta       2.4113220099811957e-081.9597769516214344e-081.5890722374686815e-08
# Theta       1.7800973057666667e-091.560479628015059e-091.2870911194102388e-09
# Alpha       6.028185707562749e-106.14210870098583e-105.624703623191491e-10
# Beta Low    1.7747029965658868e-101.6492627909664682e-101.4220325082723444e-10
# Beta High   7.927146640277591e-117.516714402841291e-116.618411749653952e-11
# Gamma       7.476151477281838e-117.147968544160986e-116.407720842635391e-11

# %%
import mne
from mne.preprocessing import ICA
from tabulate import tabulate

# Define EEG channels and brain waves
eeg_channels = ['Cz', 'Fz', 'Fp1', 'F7', 'F3', 'FC1', 'C3', 'FC5', 'FT9', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'PO9', 'O1', 'Pz', 'Oz', 'O2', 'PO10', 'P8', 'P4', 'CP2', 'CP6', 'T8', 'FT10', 'FC6', 'C4', 'FC2', 'F4', 'F8', 'Fp2']

brain_waves = {
    'Delta': (0.1, 4),
    'Theta': (4, 8),
    'Alpha': (8, 13),
    'Beta Low': (13, 20),
    'Beta High': (20, 30),
    'Gamma': (30, 40)
}

# Define lobes and corresponding electrodes
brain_lobes = {
    'Frontal': ['Fz', 'Fp1', 'F7', 'F3', 'FC1', 'Fp2', 'FC2', 'F4', 'F8'],
    'Temporal': ['FT9', 'T7', 'FT10', 'T8'],
    'Parietal': ['Cz', 'C3', 'CP5', 'CP1', 'P3', 'P7', 'Pz', 'P4', 'CP2', 'CP6'],
    'Occipital': ['PO9', 'O1', 'Oz', 'O2', 'PO10']
}

# Load the raw EEG data
raw = mne.io.read_raw_edf(
    r'EDF+\254362\254362.edf',
    preload=True,
    infer_types=True
)

# Set montage and pick the specified EEG channels
montage = mne.channels.make_standard_montage('standard_1020')
raw.set_montage(montage, on_missing='ignore')
raw.pick_channels(eeg_channels)

# Filter the data (1-40 Hz)
filtered = raw.copy().filter(l_freq=1, h_freq=40)

# Apply ICA to remove artifacts
ica = ICA(n_components=32, random_state=97, max_iter="auto")
ica.fit(filtered)

# Find and exclude EOG and muscle artifacts
eog_indices, _ = ica.find_bads_eog(filtered, ch_name=['Fp1', 'Fp2'])
muscle_noise_indices, _ = ica.find_bads_muscle(filtered)
ica.exclude = list(set(eog_indices + muscle_noise_indices))

# Apply the ICA correction
filtered_clean = ica.apply(filtered.copy())

# Compute PSD (power spectral density)
psd = filtered_clean.compute_psd(
    method='multitaper',
    fmin=1, fmax=40,
    tmin=0, tmax=60,
    picks='eeg',
    proj=False
)

# Convert PSD data to DataFrame
df = psd.to_data_frame(picks=eeg_channels)

# Function to compute statistics for brain lobes and brain waves
def compute_stats_for_lobes(lobe_electrodes, df, brain_waves):
    lobe_statistics = {}
    for lobe, electrodes in lobe_electrodes.items():
        lobe_statistics[lobe] = {}
        for wave, (min_freq, max_freq) in brain_waves.items():
            filtered_rows = df[(df['freq'] >= min_freq) & (df['freq'] <= max_freq)][electrodes]
            if not filtered_rows.empty:
                avg_across_electrodes = filtered_rows.mean(axis=1)
                lobe_statistics[lobe][wave] = avg_across_electrodes.mean()
    return lobe_statistics

# Compute the statistics for each lobe and wave
brain_wave_lobe_stats = compute_stats_for_lobes(brain_lobes, df, brain_waves)

# Collect data for table
table_data = []
for lobe in brain_lobes.keys():
    for wave in brain_waves.keys():
        avg_value = brain_wave_lobe_stats[lobe].get(wave, 'N/A')
        row = [
            lobe,
            wave,
            f"{avg_value:.2f}" if isinstance(avg_value, float) else 'N/A'
        ]
        table_data.append(row)

# Print the table
print(tabulate(table_data, headers=['Lobe', 'Brain Wave', 'Average Power'], tablefmt='grid'))

# Calculate and display statistics for left, right, and midline regions
lobes_combined = {
    'Left': brain_lobes['Frontal'][:5] + brain_lobes['Temporal'][:2] + brain_lobes['Parietal'][1:4] + brain_lobes['Occipital'][:2],
    'Right': brain_lobes['Frontal'][5:] + brain_lobes['Temporal'][2:] + brain_lobes['Parietal'][4:8] + brain_lobes['Occipital'][2:],
    'Midline': ['Cz', 'Pz', 'Oz']
}

combined_stats = compute_stats_for_lobes(lobes_combined, df, brain_waves)

# Prepare combined stats table
combined_table_data = []
for wave in brain_waves.keys():
    left_value = combined_stats['Left'].get(wave, 'N/A')
    right_value = combined_stats['Right'].get(wave, 'N/A')
    mid_value = combined_stats['Midline'].get(wave, 'N/A')
    total_value = (left_value + right_value + mid_value) / 3 if isinstance(left_value, float) else 'N/A'
    row = [
        wave,
        f"{left_value:.2f}" if isinstance(left_value, float) else 'N/A',
        f"{total_value:.2f}" if isinstance(total_value, float) else 'N/A',
        f"{right_value:.2f}" if isinstance(right_value, float) else 'N/A',
    ]
    combined_table_data.append(row)

# Print the combined statistics table
print(tabulate(combined_table_data, headers=['Brain Wave', 'Left', 'Total (with Midline)', 'Right'], tablefmt='grid'))
# Out:
# Extracting EDF parameters from r:\FINAL_EDF_REPO\EDF_analysis\EDF+\254362\254362.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 143999  =      0.000 ...  1124.992 secs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
#
# Fitting ICA to data using 32 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Selecting by number: 32 components
# Fitting ICA took 9.6s.
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Effective window size : 16.000 (s)
# Applying ICA to Raw instance
#     Transforming to ICA space (32 components)
#     Zeroing out 19 ICA components
#     Projecting back using 32 PCA components
#     Using multitaper spectrum estimation with 7 DPSS windows
# +-----------+--------------+-----------------+
# | Lobe      | Brain Wave   |   Average Power |
# +===========+==============+=================+
# | Frontal   | Delta        |               0 |
# +-----------+--------------+-----------------+
# | Frontal   | Theta        |               0 |
# +-----------+--------------+-----------------+
# | Frontal   | Alpha        |               0 |
# +-----------+--------------+-----------------+
# | Frontal   | Beta Low     |               0 |
# +-----------+--------------+-----------------+
# | Frontal   | Beta High    |               0 |
# +-----------+--------------+-----------------+
# | Frontal   | Gamma        |               0 |
# +-----------+--------------+-----------------+
# | Temporal  | Delta        |               0 |
# +-----------+--------------+-----------------+
# | Temporal  | Theta        |               0 |
# +-----------+--------------+-----------------+
# | Temporal  | Alpha        |               0 |
# +-----------+--------------+-----------------+
# | Temporal  | Beta Low     |               0 |
# +-----------+--------------+-----------------+
# | Temporal  | Beta High    |               0 |
# +-----------+--------------+-----------------+
# | Temporal  | Gamma        |               0 |
# +-----------+--------------+-----------------+
# | Parietal  | Delta        |               0 |
# +-----------+--------------+-----------------+
# | Parietal  | Theta        |               0 |
# +-----------+--------------+-----------------+
# | Parietal  | Alpha        |               0 |
# +-----------+--------------+-----------------+
# | Parietal  | Beta Low     |               0 |
# +-----------+--------------+-----------------+
# | Parietal  | Beta High    |               0 |
# +-----------+--------------+-----------------+
# | Parietal  | Gamma        |               0 |
# +-----------+--------------+-----------------+
# | Occipital | Delta        |               0 |
# +-----------+--------------+-----------------+
# | Occipital | Theta        |               0 |
# +-----------+--------------+-----------------+
# | Occipital | Alpha        |               0 |
# +-----------+--------------+-----------------+
# | Occipital | Beta Low     |               0 |
# +-----------+--------------+-----------------+
# | Occipital | Beta High    |               0 |
# +-----------+--------------+-----------------+
# | Occipital | Gamma        |               0 |
# +-----------+--------------+-----------------+
# +--------------+--------+------------------------+---------+
# | Brain Wave   |   Left |   Total (with Midline) |   Right |
# +==============+========+========================+=========+
# | Delta        |      0 |                      0 |       0 |
# +--------------+--------+------------------------+---------+
# | Theta        |      0 |                      0 |       0 |
# +--------------+--------+------------------------+---------+
# | Alpha        |      0 |                      0 |       0 |
# +--------------+--------+------------------------+---------+
# | Beta Low     |      0 |                      0 |       0 |
# +--------------+--------+------------------------+---------+
# | Beta High    |      0 |                      0 |       0 |
# +--------------+--------+------------------------+---------+
# | Gamma        |      0 |                      0 |       0 |
# +--------------+--------+------------------------+---------+

# %%
import mne
from mne.preprocessing import ICA
import numpy as np

plot = False

# Define eeg channels
eeg_channels = ['Cz', 'Fz', 'Fp1', 'F7', 'F3', 'FC1', 'C3', 'FC5', 'FT9', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'PO9', 'O1', 'Pz', 'Oz', 'O2', 'PO10', 'P8', 'P4', 'CP2', 'CP6', 'T8', 'FT10', 'FC6', 'C4', 'FC2', 'F4', 'F8', 'Fp2']
eog_channels = ['Fp1', 'Fp2']

# Load raw data
raw = mne.io.read_raw_edf(
    r'EDF+\254362\254362.edf',
    misc=None,
    stim_channel=None,
    exclude=[],
    preload=True,
    infer_types=True,
    verbose=True
)

montage = mne.channels.make_standard_montage('standard_1020')
raw.set_montage(montage, on_missing='ignore')
raw.pick('eeg')

# Filter the data
filtered = raw.copy().filter(l_freq=1, h_freq=40)

# Apply ICA to the raw data
ica = ICA(n_components=32, random_state=97, max_iter="auto")
ica.fit(filtered)

# Find and exclude artifacts
eog_indices, eog_scores = ica.find_bads_eog(filtered, ch_name=['Fp1', 'Fp2'])
muscle_noise_indices, muscle_noise_scores = ica.find_bads_muscle(filtered)
ica.exclude = list(set(eog_indices + muscle_noise_indices))

# Apply ICA to the raw data
filtered_clean = ica.apply(filtered.copy())

# Define brain waves
brain_waves = {
    'Delta': (0.1, 4),
    'Theta': (4, 8),
    'Alpha': (8, 13),
    'Beta Low': (13, 20),
    'Beta High': (20, 30),
    'Gamma': (30, 40)
}

# Define brain lobes
brain_lobes = {
    'Frontal': ['Fz', 'Fp1', 'F7', 'F3', 'FC1', 'Fp2', 'FC2', 'F4', 'F8'],
    'Temporal': ['FT9', 'T7', 'FT10', 'T8'],
    'Parietal': ['Cz', 'C3', 'CP5', 'CP1', 'P3', 'P7', 'Pz', 'P4', 'CP2', 'CP6'],
    'Occipital': ['PO9', 'O1', 'Oz', 'O2', 'PO10']
}

# Initialize data structures
brain_wave_lobes = {lobe: {wave: None for wave in brain_waves} for lobe in brain_lobes}
brain_wave_lobes_avg = {lobe: {wave: None for wave in brain_waves} for lobe in brain_lobes}

# Compute the power spectral density
pdf_value = filtered_clean.compute_psd(
    method='multitaper',
    fmin=1,
    fmax=40,
    tmin=0,
    tmax=60,
    picks='eeg',
    proj=False
)

df = pdf_value.to_data_frame(picks=eeg_channels)

# Populate brain_wave_lobes with filtered DataFrame rows for each lobe and wave
for lobe, electrodes in brain_lobes.items():
    for wave, (min_freq, max_freq) in brain_waves.items():
        filtered_rows = df[(df['freq'] >= min_freq) & (df['freq'] <= max_freq)][electrodes]
        brain_wave_lobes[lobe][wave] = filtered_rows

# Calculate statistics for each brain wave per electrode location within each lobe
brain_wave_lobes_statistics = {lobe: {wave: {} for wave in brain_waves} for lobe in brain_lobes}
for lobe, waves in brain_wave_lobes.items():
    for wave, rows in waves.items():
        for col in rows.columns:
            desc = rows[col].describe(percentiles=[.25, .5, .75])
            median = rows[col].median()
            brain_wave_lobes_statistics[lobe][wave][col] = {
                'count': desc['count'],
                'mean': desc['mean'],
                'std': desc['std'],
                'min': desc['min'],
                '25%': desc['25%'],
                '50%': median,
                '75%': desc['75%'],
                'max': desc['max'],
            }

# Calculate average across all electrodes within each brain lobe for each brain wave
for lobe, electrodes in brain_lobes.items():
    for wave, (min_freq, max_freq) in brain_waves.items():
        filtered_rows = df[(df['freq'] >= min_freq) & (df['freq'] <= max_freq)][electrodes]
        avg_across_electrodes = filtered_rows.mean(axis=1)  # Calculate mean across electrodes
        brain_wave_lobes_avg[lobe][wave] = avg_across_electrodes.mean()  # Mean of means across frequencies

# Function to format numbers in scientific notation with 3 significant digits
def format_sci(value):
    return f'{value:.3e}'

# Print the statistics in the required format
print('Brain Wave  Left      Total     Right')
for wave in brain_waves.keys():
    left_avg = brain_wave_lobes_avg['Frontal'][wave] if 'Frontal' in brain_wave_lobes_avg else 0
    total_avg = brain_wave_lobes_avg['Frontal'][wave] + brain_wave_lobes_avg['Temporal'][wave] + \
                brain_wave_lobes_avg['Parietal'][wave] + brain_wave_lobes_avg['Occipital'][wave] if 'Frontal' in brain_wave_lobes_avg and 'Temporal' in brain_wave_lobes_avg and 'Parietal' in brain_wave_lobes_avg and 'Occipital' in brain_wave_lobes_avg else 0
    right_avg = brain_wave_lobes_avg['Temporal'][wave] + brain_wave_lobes_avg['Occipital'][wave] if 'Temporal' in brain_wave_lobes_avg and 'Occipital' in brain_wave_lobes_avg else 0
    
    print(f'{wave:<10} {format_sci(left_avg):<10} {format_sci(total_avg):<10} {format_sci(right_avg)}')
# Out:
# Extracting EDF parameters from r:\FINAL_EDF_REPO\EDF_analysis\EDF+\254362\254362.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 143999  =      0.000 ...  1124.992 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.4s
# Fitting ICA to data using 127 channels (please be patient, this may take a while)
# Selecting by number: 32 components
# Fitting ICA took 8.4s.
# Using EOG channels: Fp1, Fp2
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4740\341019098.py:31: RuntimeWarning: Using n_components=32 (resulting in n_components_=32) may lead to an unstable mixing matrix estimation because the ratio between the largest (1.2e+02) and smallest (3.6e-07) variances is too large (> 1e6); consider setting n_components=0.999999 or an integer <= 10
#   ica.fit(filtered)
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Effective window size : 16.000 (s)
# Applying ICA to Raw instance
#     Transforming to ICA space (32 components)
#     Zeroing out 0 ICA components
#     Projecting back using 127 PCA components
#     Using multitaper spectrum estimation with 7 DPSS windows
# Brain Wave  Left      Total     Right
# Delta      2.822e-08  1.040e-07  5.403e-08
# Theta      2.337e-09  8.049e-09  4.035e-09
# Alpha      6.816e-10  3.002e-09  1.551e-09
# Beta Low   2.237e-10  8.515e-10  4.729e-10
# Beta High  1.063e-10  3.961e-10  2.208e-10
# Gamma      8.896e-11  3.570e-10  2.062e-10

# %%
import mne
from mne.preprocessing import ICA
import numpy as np
from tabulate import tabulate

plot = False

# Define eeg channels
eeg_channels = ['Cz', 'Fz', 'Fp1', 'F7', 'F3', 'FC1', 'C3', 'FC5', 'FT9', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'PO9', 'O1', 'Pz', 'Oz', 'O2', 'PO10', 'P8', 'P4', 'CP2', 'CP6', 'T8', 'FT10', 'FC6', 'C4', 'FC2', 'F4', 'F8', 'Fp2']
eog_channels = ['Fp1', 'Fp2']

# Load raw data
raw = mne.io.read_raw_edf(
    r'EDF+\254362\254362.edf',
    misc=None,
    stim_channel=None,
    exclude=[],
    preload=True,
    infer_types=True,
    verbose=True
)

montage = mne.channels.make_standard_montage('standard_1020')
raw.set_montage(montage, on_missing='ignore')
raw.pick('eeg')

# Filter the data
filtered = raw.copy().filter(l_freq=1, h_freq=40)

# Apply ICA to the raw data
ica = ICA(n_components=32, random_state=97, max_iter="auto")
ica.fit(filtered)

# Find and exclude artifacts
eog_indices, eog_scores = ica.find_bads_eog(filtered, ch_name=['Fp1', 'Fp2'])
muscle_noise_indices, muscle_noise_scores = ica.find_bads_muscle(filtered)
ica.exclude = list(set(eog_indices + muscle_noise_indices))

# Apply ICA to the raw data
filtered_clean = ica.apply(filtered.copy())

# Define brain waves
brain_waves = {
    'Delta': (0.1, 4),
    'Theta': (4, 8),
    'Alpha': (8, 13),
    'Beta Low': (13, 20),
    'Beta High': (20, 30),
    'Gamma': (30, 40)
}

# Define brain lobes
brain_lobes = {
    'Frontal': ['Fz', 'Fp1', 'F7', 'F3', 'FC1', 'Fp2', 'FC2', 'F4', 'F8'],
    'Temporal': ['FT9', 'T7', 'FT10', 'T8'],
    'Parietal': ['Cz', 'C3', 'CP5', 'CP1', 'P3', 'P7', 'Pz', 'P4', 'CP2', 'CP6'],
    'Occipital': ['PO9', 'O1', 'Oz', 'O2', 'PO10']
}

# Initialize data structures
brain_wave_lobes = {lobe: {wave: None for wave in brain_waves} for lobe in brain_lobes}
brain_wave_lobes_avg = {lobe: {wave: None for wave in brain_waves} for lobe in brain_lobes}

# Compute the power spectral density
pdf_value = filtered_clean.compute_psd(
    method='multitaper',
    fmin=1,
    fmax=40,
    tmin=0,
    tmax=60,
    picks='eeg',
    proj=False
)

df = pdf_value.to_data_frame(picks=eeg_channels)

# Populate brain_wave_lobes with filtered DataFrame rows for each lobe and wave
for lobe, electrodes in brain_lobes.items():
    for wave, (min_freq, max_freq) in brain_waves.items():
        filtered_rows = df[(df['freq'] >= min_freq) & (df['freq'] <= max_freq)][electrodes]
        brain_wave_lobes[lobe][wave] = filtered_rows

# Calculate average across all electrodes within each brain lobe for each brain wave
for lobe, electrodes in brain_lobes.items():
    for wave, (min_freq, max_freq) in brain_waves.items():
        filtered_rows = df[(df['freq'] >= min_freq) & (df['freq'] <= max_freq)][electrodes]
        avg_across_electrodes = filtered_rows.mean(axis=1)  # Calculate mean across electrodes
        brain_wave_lobes_avg[lobe][wave] = avg_across_electrodes.mean()  # Mean of means across frequencies

# Function to format numbers in scientific notation with 3 significant digits
def format_sci(value):
    return f'{value:.3e}'

# Print the statistics by brain lobe
for lobe, waves in brain_wave_lobes_avg.items():
    print(f'{lobe} average statistics:')
    for wave, value in waves.items():
        print(f'  {wave}: {format_sci(value)}')

print('\nBrain Wave  Left      Total     Right')

# Calculate Left, Total, Right for the tabular output
results = []
for wave in brain_waves.keys():
    left_avg = brain_wave_lobes_avg['Frontal'][wave] if 'Frontal' in brain_wave_lobes_avg else 0
    total_avg = sum(brain_wave_lobes_avg[lobe][wave] for lobe in brain_lobes) if all(lobe in brain_wave_lobes_avg for lobe in brain_lobes) else 0
    right_avg = brain_wave_lobes_avg['Temporal'][wave] + brain_wave_lobes_avg['Occipital'][wave] if 'Temporal' in brain_wave_lobes_avg and 'Occipital' in brain_wave_lobes_avg else 0
    
    results.append([wave, format_sci(left_avg), format_sci(total_avg), format_sci(right_avg)])

# Print the results in tabular format
print(tabulate(results, headers=['Brain Wave', 'Left', 'Total', 'Right'], tablefmt='plain'))
# Out:
# Extracting EDF parameters from r:\FINAL_EDF_REPO\EDF_analysis\EDF+\254362\254362.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 143999  =      0.000 ...  1124.992 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 423 samples (3.305 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.4s
# Fitting ICA to data using 127 channels (please be patient, this may take a while)
# Selecting by number: 32 components
# Fitting ICA took 8.5s.
# Using EOG channels: Fp1, Fp2
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4740\4038382859.py:32: RuntimeWarning: Using n_components=32 (resulting in n_components_=32) may lead to an unstable mixing matrix estimation because the ratio between the largest (1.2e+02) and smallest (3.6e-07) variances is too large (> 1e6); consider setting n_components=0.999999 or an integer <= 10
#   ica.fit(filtered)
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 1280 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Effective window size : 16.000 (s)
# Applying ICA to Raw instance
#     Transforming to ICA space (32 components)
#     Zeroing out 0 ICA components
#     Projecting back using 127 PCA components
#     Using multitaper spectrum estimation with 7 DPSS windows
# Frontal average statistics:
#   Delta: 2.822e-08
#   Theta: 2.337e-09
#   Alpha: 6.816e-10
#   Beta Low: 2.237e-10
#   Beta High: 1.063e-10
#   Gamma: 8.896e-11
# Temporal average statistics:
#   Delta: 2.636e-08
#   Theta: 2.081e-09
#   Alpha: 6.634e-10
#   Beta Low: 2.358e-10
#   Beta High: 1.168e-10
#   Gamma: 1.141e-10
# Parietal average statistics:
#   Delta: 2.178e-08
#   Theta: 1.677e-09
#   Alpha: 7.697e-10
#   Beta Low: 1.549e-10
#   Beta High: 6.904e-11
#   Gamma: 6.185e-11
# Occipital average statistics:
#   Delta: 2.768e-08
#   Theta: 1.954e-09
#   Alpha: 8.877e-10
#   Beta Low: 2.371e-10
#   Beta High: 1.040e-10
#   Gamma: 9.217e-11
#
# Brain Wave  Left      Total     Right
# Brain Wave         Left      Total      Right
# Delta         2.822e-08  1.04e-07   5.403e-08
# Theta         2.337e-09  8.049e-09  4.035e-09
# Alpha         6.816e-10  3.002e-09  1.551e-09
# Beta Low      2.237e-10  8.515e-10  4.729e-10
# Beta High     1.063e-10  3.961e-10  2.208e-10
# Gamma         8.896e-11  3.57e-10   2.062e-10
